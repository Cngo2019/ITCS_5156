# %% [markdown]
# ## Improving out model
#
#
# Previously, we found out at the surface that random forests gives us the best accuracy and AUC among all models we tried.
#
# Here, we can try and tune our model or feature selection results

# %%
### Reading the files
import pandas as pd
import numpy as np
X_train = pd.read_csv("X_train", delimiter = ",")
X_test = pd.read_csv("X_test", delimiter = ",")
t_train = pd.read_csv("t_train", delimiter = ",")
t_test = pd.read_csv("t_test",  delimiter = ",")
X_train_rs = pd.read_csv("X_train_rs", delimiter = ",")
t_train_rs = pd.read_csv("t_train_rs", delimiter = ",")

# %% [markdown]
# ## Here, we will end up training the model

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# Source: https://stackoverflow.com/questions/32612180/eliminating-warnings-from-scikit-learn
# Source: https://scikit-learn.org/stable/modules/generated/sklearn.exceptions.DataConversionWarning.html
from sklearn.model_selection import GridSearchCV
#Source: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
# Source: https://scikit-learn.org/stable/modules/grid_search.html
pipe = Pipeline([
    ('select', SelectKBest()),
    ('model', RandomForestClassifier(max_depth = 15))]) 

parameters = {
    'model__n_estimators': [50, 100],
    'model__criterion': ['gini', 'entropy'],
    'select__k': [15,20,25,30,35,40,47]
}

sc = StandardScaler()
sc.fit(X_train)
X_train_sc = sc.transform(X_train)
gs = GridSearchCV(estimator = pipe, param_grid = parameters, verbose = 10)
gs.fit(X_train_sc, t_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [CV 1/5; 1/28] START model__criterion=gini, model__n_estimators=50, select__k=15
# [CV 1/5; 1/28] END model__criterion=gini, model__n_estimators=50, select__k=15;, score=0.633 total time=   3.2s
# [CV 2/5; 1/28] START model__criterion=gini, model__n_estimators=50, select__k=15
# [CV 2/5; 1/28] END model__criterion=gini, model__n_estimators=50, select__k=15;, score=0.633 total time=   3.2s
# [CV 3/5; 1/28] START model__criterion=gini, model__n_estimators=50, select__k=15
# [CV 3/5; 1/28] END model__criterion=gini, model__n_estimators=50, select__k=15;, score=0.633 total time=   3.0s
# [CV 4/5; 1/28] START model__criterion=gini, model__n_estimators=50, select__k=15
# [CV 4/5; 1/28] END model__criterion=gini, model__n_estimators=50, select__k=15;, score=0.633 total time=   2.9s
# [CV 5/5; 1/28] START model__criterion=gini, model__n_estimators=50, select__k=15
# [CV 5/5; 1/28] END model__criterion=gini, model__n_estimators=50, select__k=15;, score=0.636 total time=   3.4s
# [CV 1/5; 2/28] START model__criterion=gini, model__n_estimators=50, select__k=20
# [CV 1/5; 2/28] END model__criterion=gini, model__n_estimators=50, select__k=20;, score=0.634 total time=   4.1s
# [CV 2/5; 2/28] START model__criterion=gini, model__n_estimators=50, select__k=20
# [CV 2/5; 2/28] END model__criterion=gini, model__n_estimators=50, select__k=20;, score=0.636 total time=   3.8s
# [CV 3/5; 2/28] START model__criterion=gini, model__n_estimators=50, select__k=20
# [CV 3/5; 2/28] END model__criterion=gini, model__n_estimators=50, select__k=20;, score=0.631 total time=   3.8s
# [CV 4/5; 2/28] START model__criterion=gini, model__n_estimators=50, select__k=20
# [CV 4/5; 2/28] END model__criterion=gini, model__n_estimators=50, select__k=20;, score=0.646 total time=   4.0s
# [CV 5/5; 2/28] START model__criterion=gini, model__n_estimators=50, select__k=20
# [CV 5/5; 2/28] END model__criterion=gini, model__n_estimators=50, select__k=20;, score=0.647 total time=   3.9s
# [CV 1/5; 3/28] START model__criterion=gini, model__n_estimators=50, select__k=25
# [CV 1/5; 3/28] END model__criterion=gini, model__n_estimators=50, select__k=25;, score=0.645 total time=   4.3s
# [CV 2/5; 3/28] START model__criterion=gini, model__n_estimators=50, select__k=25
# [CV 2/5; 3/28] END model__criterion=gini, model__n_estimators=50, select__k=25;, score=0.647 total time=   4.5s
# [CV 3/5; 3/28] START model__criterion=gini, model__n_estimators=50, select__k=25
# [CV 3/5; 3/28] END model__criterion=gini, model__n_estimators=50, select__k=25;, score=0.645 total time=   4.2s
# [CV 4/5; 3/28] START model__criterion=gini, model__n_estimators=50, select__k=25
# [CV 4/5; 3/28] END model__criterion=gini, model__n_estimators=50, select__k=25;, score=0.646 total time=   4.9s
# [CV 5/5; 3/28] START model__criterion=gini, model__n_estimators=50, select__k=25
# [CV 5/5; 3/28] END model__criterion=gini, model__n_estimators=50, select__k=25;, score=0.645 total time=   4.7s
# [CV 1/5; 4/28] START model__criterion=gini, model__n_estimators=50, select__k=30
# [CV 1/5; 4/28] END model__criterion=gini, model__n_estimators=50, select__k=30;, score=0.646 total time=   4.8s
# [CV 2/5; 4/28] START model__criterion=gini, model__n_estimators=50, select__k=30
# [CV 2/5; 4/28] END model__criterion=gini, model__n_estimators=50, select__k=30;, score=0.643 total time=   5.8s
# [CV 3/5; 4/28] START model__criterion=gini, model__n_estimators=50, select__k=30
# [CV 3/5; 4/28] END model__criterion=gini, model__n_estimators=50, select__k=30;, score=0.647 total time=   6.1s
# [CV 4/5; 4/28] START model__criterion=gini, model__n_estimators=50, select__k=30
# [CV 4/5; 4/28] END model__criterion=gini, model__n_estimators=50, select__k=30;, score=0.648 total time=   6.2s
# [CV 5/5; 4/28] START model__criterion=gini, model__n_estimators=50, select__k=30
# [CV 5/5; 4/28] END model__criterion=gini, model__n_estimators=50, select__k=30;, score=0.644 total time=   4.4s
# [CV 1/5; 5/28] START model__criterion=gini, model__n_estimators=50, select__k=35
# [CV 1/5; 5/28] END model__criterion=gini, model__n_estimators=50, select__k=35;, score=0.645 total time=   4.1s
# [CV 2/5; 5/28] START model__criterion=gini, model__n_estimators=50, select__k=35
# [CV 2/5; 5/28] END model__criterion=gini, model__n_estimators=50, select__k=35;, score=0.648 total time=   4.2s
# [CV 3/5; 5/28] START model__criterion=gini, model__n_estimators=50, select__k=35
# [CV 3/5; 5/28] END model__criterion=gini, model__n_estimators=50, select__k=35;, score=0.643 total time=   4.3s
# [CV 4/5; 5/28] START model__criterion=gini, model__n_estimators=50, select__k=35
# [CV 4/5; 5/28] END model__criterion=gini, model__n_estimators=50, select__k=35;, score=0.650 total time=   4.4s
# [CV 5/5; 5/28] START model__criterion=gini, model__n_estimators=50, select__k=35
# [CV 5/5; 5/28] END model__criterion=gini, model__n_estimators=50, select__k=35;, score=0.644 total time=   4.1s
# [CV 1/5; 6/28] START model__criterion=gini, model__n_estimators=50, select__k=40
# [CV 1/5; 6/28] END model__criterion=gini, model__n_estimators=50, select__k=40;, score=0.647 total time=   5.4s
# [CV 2/5; 6/28] START model__criterion=gini, model__n_estimators=50, select__k=40
# [CV 2/5; 6/28] END model__criterion=gini, model__n_estimators=50, select__k=40;, score=0.647 total time=   5.6s
# [CV 3/5; 6/28] START model__criterion=gini, model__n_estimators=50, select__k=40
# [CV 3/5; 6/28] END model__criterion=gini, model__n_estimators=50, select__k=40;, score=0.645 total time=   5.9s
# [CV 4/5; 6/28] START model__criterion=gini, model__n_estimators=50, select__k=40
# [CV 4/5; 6/28] END model__criterion=gini, model__n_estimators=50, select__k=40;, score=0.648 total time=   4.9s
# [CV 5/5; 6/28] START model__criterion=gini, model__n_estimators=50, select__k=40
# [CV 5/5; 6/28] END model__criterion=gini, model__n_estimators=50, select__k=40;, score=0.644 total time=   5.1s
# [CV 1/5; 7/28] START model__criterion=gini, model__n_estimators=50, select__k=47
# [CV 1/5; 7/28] END model__criterion=gini, model__n_estimators=50, select__k=47;, score=0.645 total time=   4.3s
# [CV 2/5; 7/28] START model__criterion=gini, model__n_estimators=50, select__k=47
# [CV 2/5; 7/28] END model__criterion=gini, model__n_estimators=50, select__k=47;, score=0.648 total time=   5.5s
# [CV 3/5; 7/28] START model__criterion=gini, model__n_estimators=50, select__k=47
# [CV 3/5; 7/28] END model__criterion=gini, model__n_estimators=50, select__k=47;, score=0.641 total time=   5.5s
# [CV 4/5; 7/28] START model__criterion=gini, model__n_estimators=50, select__k=47
# [CV 4/5; 7/28] END model__criterion=gini, model__n_estimators=50, select__k=47;, score=0.645 total time=   4.8s
# [CV 5/5; 7/28] START model__criterion=gini, model__n_estimators=50, select__k=47
# [CV 5/5; 7/28] END model__criterion=gini, model__n_estimators=50, select__k=47;, score=0.644 total time=   4.7s
# [CV 1/5; 8/28] START model__criterion=gini, model__n_estimators=100, select__k=15
# [CV 1/5; 8/28] END model__criterion=gini, model__n_estimators=100, select__k=15;, score=0.635 total time=   7.1s
# [CV 2/5; 8/28] START model__criterion=gini, model__n_estimators=100, select__k=15
# [CV 2/5; 8/28] END model__criterion=gini, model__n_estimators=100, select__k=15;, score=0.637 total time=   7.5s
# [CV 3/5; 8/28] START model__criterion=gini, model__n_estimators=100, select__k=15
# [CV 3/5; 8/28] END model__criterion=gini, model__n_estimators=100, select__k=15;, score=0.633 total time=   6.5s
# [CV 4/5; 8/28] START model__criterion=gini, model__n_estimators=100, select__k=15
# [CV 4/5; 8/28] END model__criterion=gini, model__n_estimators=100, select__k=15;, score=0.636 total time=   6.3s
# [CV 5/5; 8/28] START model__criterion=gini, model__n_estimators=100, select__k=15
# [CV 5/5; 8/28] END model__criterion=gini, model__n_estimators=100, select__k=15;, score=0.635 total time=   6.6s
# [CV 1/5; 9/28] START model__criterion=gini, model__n_estimators=100, select__k=20
# [CV 1/5; 9/28] END model__criterion=gini, model__n_estimators=100, select__k=20;, score=0.636 total time=   7.6s
# [CV 2/5; 9/28] START model__criterion=gini, model__n_estimators=100, select__k=20
# [CV 2/5; 9/28] END model__criterion=gini, model__n_estimators=100, select__k=20;, score=0.638 total time=   8.5s
# [CV 3/5; 9/28] START model__criterion=gini, model__n_estimators=100, select__k=20
# [CV 3/5; 9/28] END model__criterion=gini, model__n_estimators=100, select__k=20;, score=0.635 total time=   8.0s
# [CV 4/5; 9/28] START model__criterion=gini, model__n_estimators=100, select__k=20
# [CV 4/5; 9/28] END model__criterion=gini, model__n_estimators=100, select__k=20;, score=0.648 total time=   7.8s
# [CV 5/5; 9/28] START model__criterion=gini, model__n_estimators=100, select__k=20
# [CV 5/5; 9/28] END model__criterion=gini, model__n_estimators=100, select__k=20;, score=0.643 total time=   7.4s
# [CV 1/5; 10/28] START model__criterion=gini, model__n_estimators=100, select__k=25
# [CV 1/5; 10/28] END model__criterion=gini, model__n_estimators=100, select__k=25;, score=0.648 total time=   8.7s
# [CV 2/5; 10/28] START model__criterion=gini, model__n_estimators=100, select__k=25
# [CV 2/5; 10/28] END model__criterion=gini, model__n_estimators=100, select__k=25;, score=0.648 total time=  10.3s
# [CV 3/5; 10/28] START model__criterion=gini, model__n_estimators=100, select__k=25
# [CV 3/5; 10/28] END model__criterion=gini, model__n_estimators=100, select__k=25;, score=0.644 total time=   9.1s
# [CV 4/5; 10/28] START model__criterion=gini, model__n_estimators=100, select__k=25
# [CV 4/5; 10/28] END model__criterion=gini, model__n_estimators=100, select__k=25;, score=0.646 total time=   8.8s
# [CV 5/5; 10/28] START model__criterion=gini, model__n_estimators=100, select__k=25
# [CV 5/5; 10/28] END model__criterion=gini, model__n_estimators=100, select__k=25;, score=0.645 total time=   9.1s
# [CV 1/5; 11/28] START model__criterion=gini, model__n_estimators=100, select__k=30
# [CV 1/5; 11/28] END model__criterion=gini, model__n_estimators=100, select__k=30;, score=0.650 total time=   9.2s
# [CV 2/5; 11/28] START model__criterion=gini, model__n_estimators=100, select__k=30
# [CV 2/5; 11/28] END model__criterion=gini, model__n_estimators=100, select__k=30;, score=0.647 total time=   9.2s
# [CV 3/5; 11/28] START model__criterion=gini, model__n_estimators=100, select__k=30
# [CV 3/5; 11/28] END model__criterion=gini, model__n_estimators=100, select__k=30;, score=0.647 total time=   9.9s
# [CV 4/5; 11/28] START model__criterion=gini, model__n_estimators=100, select__k=30
# [CV 4/5; 11/28] END model__criterion=gini, model__n_estimators=100, select__k=30;, score=0.650 total time=   8.7s
# [CV 5/5; 11/28] START model__criterion=gini, model__n_estimators=100, select__k=30
# [CV 5/5; 11/28] END model__criterion=gini, model__n_estimators=100, select__k=30;, score=0.646 total time=   8.9s
# [CV 1/5; 12/28] START model__criterion=gini, model__n_estimators=100, select__k=35
# [CV 1/5; 12/28] END model__criterion=gini, model__n_estimators=100, select__k=35;, score=0.650 total time=   8.2s
# [CV 2/5; 12/28] START model__criterion=gini, model__n_estimators=100, select__k=35
# [CV 2/5; 12/28] END model__criterion=gini, model__n_estimators=100, select__k=35;, score=0.650 total time=   8.9s
# [CV 3/5; 12/28] START model__criterion=gini, model__n_estimators=100, select__k=35
# [CV 3/5; 12/28] END model__criterion=gini, model__n_estimators=100, select__k=35;, score=0.648 total time=   8.8s
# [CV 4/5; 12/28] START model__criterion=gini, model__n_estimators=100, select__k=35
# [CV 4/5; 12/28] END model__criterion=gini, model__n_estimators=100, select__k=35;, score=0.647 total time=   8.5s
# [CV 5/5; 12/28] START model__criterion=gini, model__n_estimators=100, select__k=35
# [CV 5/5; 12/28] END model__criterion=gini, model__n_estimators=100, select__k=35;, score=0.642 total time=   8.0s
# [CV 1/5; 13/28] START model__criterion=gini, model__n_estimators=100, select__k=40
# [CV 1/5; 13/28] END model__criterion=gini, model__n_estimators=100, select__k=40;, score=0.647 total time=   9.4s
# [CV 2/5; 13/28] START model__criterion=gini, model__n_estimators=100, select__k=40
# [CV 2/5; 13/28] END model__criterion=gini, model__n_estimators=100, select__k=40;, score=0.649 total time=   8.7s
# [CV 3/5; 13/28] START model__criterion=gini, model__n_estimators=100, select__k=40
# [CV 3/5; 13/28] END model__criterion=gini, model__n_estimators=100, select__k=40;, score=0.648 total time=   8.3s
# [CV 4/5; 13/28] START model__criterion=gini, model__n_estimators=100, select__k=40
# [CV 4/5; 13/28] END model__criterion=gini, model__n_estimators=100, select__k=40;, score=0.648 total time=   8.6s
# [CV 5/5; 13/28] START model__criterion=gini, model__n_estimators=100, select__k=40
# [CV 5/5; 13/28] END model__criterion=gini, model__n_estimators=100, select__k=40;, score=0.646 total time=   8.5s
# [CV 1/5; 14/28] START model__criterion=gini, model__n_estimators=100, select__k=47
# [CV 1/5; 14/28] END model__criterion=gini, model__n_estimators=100, select__k=47;, score=0.647 total time=   7.9s
# [CV 2/5; 14/28] START model__criterion=gini, model__n_estimators=100, select__k=47
# [CV 2/5; 14/28] END model__criterion=gini, model__n_estimators=100, select__k=47;, score=0.647 total time=   7.9s
# [CV 3/5; 14/28] START model__criterion=gini, model__n_estimators=100, select__k=47
# [CV 3/5; 14/28] END model__criterion=gini, model__n_estimators=100, select__k=47;, score=0.644 total time=   8.9s
# [CV 4/5; 14/28] START model__criterion=gini, model__n_estimators=100, select__k=47
# [CV 4/5; 14/28] END model__criterion=gini, model__n_estimators=100, select__k=47;, score=0.649 total time=  12.3s
# [CV 5/5; 14/28] START model__criterion=gini, model__n_estimators=100, select__k=47
# [CV 5/5; 14/28] END model__criterion=gini, model__n_estimators=100, select__k=47;, score=0.645 total time=  10.7s
# [CV 1/5; 15/28] START model__criterion=entropy, model__n_estimators=50, select__k=15
# [CV 1/5; 15/28] END model__criterion=entropy, model__n_estimators=50, select__k=15;, score=0.632 total time=   4.3s
# [CV 2/5; 15/28] START model__criterion=entropy, model__n_estimators=50, select__k=15
# [CV 2/5; 15/28] END model__criterion=entropy, model__n_estimators=50, select__k=15;, score=0.633 total time=   4.5s
# [CV 3/5; 15/28] START model__criterion=entropy, model__n_estimators=50, select__k=15
# [CV 3/5; 15/28] END model__criterion=entropy, model__n_estimators=50, select__k=15;, score=0.631 total time=   4.1s
# [CV 4/5; 15/28] START model__criterion=entropy, model__n_estimators=50, select__k=15
# [CV 4/5; 15/28] END model__criterion=entropy, model__n_estimators=50, select__k=15;, score=0.636 total time=   4.2s
# [CV 5/5; 15/28] START model__criterion=entropy, model__n_estimators=50, select__k=15
# [CV 5/5; 15/28] END model__criterion=entropy, model__n_estimators=50, select__k=15;, score=0.634 total time=   4.4s
# [CV 1/5; 16/28] START model__criterion=entropy, model__n_estimators=50, select__k=20
# [CV 1/5; 16/28] END model__criterion=entropy, model__n_estimators=50, select__k=20;, score=0.636 total time=   5.6s
# [CV 2/5; 16/28] START model__criterion=entropy, model__n_estimators=50, select__k=20
# [CV 2/5; 16/28] END model__criterion=entropy, model__n_estimators=50, select__k=20;, score=0.635 total time=   6.0s
# [CV 3/5; 16/28] START model__criterion=entropy, model__n_estimators=50, select__k=20
# [CV 3/5; 16/28] END model__criterion=entropy, model__n_estimators=50, select__k=20;, score=0.634 total time=   6.7s
# [CV 4/5; 16/28] START model__criterion=entropy, model__n_estimators=50, select__k=20
# [CV 4/5; 16/28] END model__criterion=entropy, model__n_estimators=50, select__k=20;, score=0.645 total time=   6.8s
# [CV 5/5; 16/28] START model__criterion=entropy, model__n_estimators=50, select__k=20
# [CV 5/5; 16/28] END model__criterion=entropy, model__n_estimators=50, select__k=20;, score=0.644 total time=   6.7s
# [CV 1/5; 17/28] START model__criterion=entropy, model__n_estimators=50, select__k=25
# [CV 1/5; 17/28] END model__criterion=entropy, model__n_estimators=50, select__k=25;, score=0.645 total time=   6.6s
# [CV 2/5; 17/28] START model__criterion=entropy, model__n_estimators=50, select__k=25
# [CV 2/5; 17/28] END model__criterion=entropy, model__n_estimators=50, select__k=25;, score=0.648 total time=   6.7s
# [CV 3/5; 17/28] START model__criterion=entropy, model__n_estimators=50, select__k=25
# [CV 3/5; 17/28] END model__criterion=entropy, model__n_estimators=50, select__k=25;, score=0.645 total time=   6.4s
# [CV 4/5; 17/28] START model__criterion=entropy, model__n_estimators=50, select__k=25
# [CV 4/5; 17/28] END model__criterion=entropy, model__n_estimators=50, select__k=25;, score=0.648 total time=   7.1s
# [CV 5/5; 17/28] START model__criterion=entropy, model__n_estimators=50, select__k=25
# [CV 5/5; 17/28] END model__criterion=entropy, model__n_estimators=50, select__k=25;, score=0.642 total time=   6.8s
# [CV 1/5; 18/28] START model__criterion=entropy, model__n_estimators=50, select__k=30
# [CV 1/5; 18/28] END model__criterion=entropy, model__n_estimators=50, select__k=30;, score=0.647 total time=   6.8s
# [CV 2/5; 18/28] START model__criterion=entropy, model__n_estimators=50, select__k=30
# [CV 2/5; 18/28] END model__criterion=entropy, model__n_estimators=50, select__k=30;, score=0.647 total time=   7.1s
# [CV 3/5; 18/28] START model__criterion=entropy, model__n_estimators=50, select__k=30
# [CV 3/5; 18/28] END model__criterion=entropy, model__n_estimators=50, select__k=30;, score=0.644 total time=   6.1s
# [CV 4/5; 18/28] START model__criterion=entropy, model__n_estimators=50, select__k=30
# [CV 4/5; 18/28] END model__criterion=entropy, model__n_estimators=50, select__k=30;, score=0.649 total time=   6.2s
# [CV 5/5; 18/28] START model__criterion=entropy, model__n_estimators=50, select__k=30
# [CV 5/5; 18/28] END model__criterion=entropy, model__n_estimators=50, select__k=30;, score=0.641 total time=   6.1s
# [CV 1/5; 19/28] START model__criterion=entropy, model__n_estimators=50, select__k=35
# [CV 1/5; 19/28] END model__criterion=entropy, model__n_estimators=50, select__k=35;, score=0.644 total time=   5.5s
# [CV 2/5; 19/28] START model__criterion=entropy, model__n_estimators=50, select__k=35
# [CV 2/5; 19/28] END model__criterion=entropy, model__n_estimators=50, select__k=35;, score=0.648 total time=   5.3s
# [CV 3/5; 19/28] START model__criterion=entropy, model__n_estimators=50, select__k=35
# [CV 3/5; 19/28] END model__criterion=entropy, model__n_estimators=50, select__k=35;, score=0.645 total time=   5.4s
# [CV 4/5; 19/28] START model__criterion=entropy, model__n_estimators=50, select__k=35
# [CV 4/5; 19/28] END model__criterion=entropy, model__n_estimators=50, select__k=35;, score=0.646 total time=   5.4s
# [CV 5/5; 19/28] START model__criterion=entropy, model__n_estimators=50, select__k=35
# [CV 5/5; 19/28] END model__criterion=entropy, model__n_estimators=50, select__k=35;, score=0.643 total time=   5.6s
# [CV 1/5; 20/28] START model__criterion=entropy, model__n_estimators=50, select__k=40
# [CV 1/5; 20/28] END model__criterion=entropy, model__n_estimators=50, select__k=40;, score=0.648 total time=   6.1s
# [CV 2/5; 20/28] START model__criterion=entropy, model__n_estimators=50, select__k=40
# [CV 2/5; 20/28] END model__criterion=entropy, model__n_estimators=50, select__k=40;, score=0.648 total time=   5.8s
# [CV 3/5; 20/28] START model__criterion=entropy, model__n_estimators=50, select__k=40
# [CV 3/5; 20/28] END model__criterion=entropy, model__n_estimators=50, select__k=40;, score=0.644 total time=   6.4s
# [CV 4/5; 20/28] START model__criterion=entropy, model__n_estimators=50, select__k=40
# [CV 4/5; 20/28] END model__criterion=entropy, model__n_estimators=50, select__k=40;, score=0.647 total time=   6.8s
# [CV 5/5; 20/28] START model__criterion=entropy, model__n_estimators=50, select__k=40
# [CV 5/5; 20/28] END model__criterion=entropy, model__n_estimators=50, select__k=40;, score=0.643 total time=   6.4s
# [CV 1/5; 21/28] START model__criterion=entropy, model__n_estimators=50, select__k=47
# [CV 1/5; 21/28] END model__criterion=entropy, model__n_estimators=50, select__k=47;, score=0.647 total time=   6.1s
# [CV 2/5; 21/28] START model__criterion=entropy, model__n_estimators=50, select__k=47
# [CV 2/5; 21/28] END model__criterion=entropy, model__n_estimators=50, select__k=47;, score=0.649 total time=   7.3s
# [CV 3/5; 21/28] START model__criterion=entropy, model__n_estimators=50, select__k=47
# [CV 3/5; 21/28] END model__criterion=entropy, model__n_estimators=50, select__k=47;, score=0.643 total time=   7.2s
# [CV 4/5; 21/28] START model__criterion=entropy, model__n_estimators=50, select__k=47
# [CV 4/5; 21/28] END model__criterion=entropy, model__n_estimators=50, select__k=47;, score=0.648 total time=   6.9s
# [CV 5/5; 21/28] START model__criterion=entropy, model__n_estimators=50, select__k=47
# [CV 5/5; 21/28] END model__criterion=entropy, model__n_estimators=50, select__k=47;, score=0.644 total time=   6.0s
# [CV 1/5; 22/28] START model__criterion=entropy, model__n_estimators=100, select__k=15
# [CV 1/5; 22/28] END model__criterion=entropy, model__n_estimators=100, select__k=15;, score=0.635 total time=   9.1s
# [CV 2/5; 22/28] START model__criterion=entropy, model__n_estimators=100, select__k=15
# [CV 2/5; 22/28] END model__criterion=entropy, model__n_estimators=100, select__k=15;, score=0.636 total time=   8.9s
# [CV 3/5; 22/28] START model__criterion=entropy, model__n_estimators=100, select__k=15
# [CV 3/5; 22/28] END model__criterion=entropy, model__n_estimators=100, select__k=15;, score=0.635 total time=   8.0s
# [CV 4/5; 22/28] START model__criterion=entropy, model__n_estimators=100, select__k=15
# [CV 4/5; 22/28] END model__criterion=entropy, model__n_estimators=100, select__k=15;, score=0.638 total time=   8.1s
# [CV 5/5; 22/28] START model__criterion=entropy, model__n_estimators=100, select__k=15
# [CV 5/5; 22/28] END model__criterion=entropy, model__n_estimators=100, select__k=15;, score=0.635 total time=   8.9s
# [CV 1/5; 23/28] START model__criterion=entropy, model__n_estimators=100, select__k=20
# [CV 1/5; 23/28] END model__criterion=entropy, model__n_estimators=100, select__k=20;, score=0.638 total time=  10.0s
# [CV 2/5; 23/28] START model__criterion=entropy, model__n_estimators=100, select__k=20
# [CV 2/5; 23/28] END model__criterion=entropy, model__n_estimators=100, select__k=20;, score=0.637 total time=  10.3s
# [CV 3/5; 23/28] START model__criterion=entropy, model__n_estimators=100, select__k=20
# [CV 3/5; 23/28] END model__criterion=entropy, model__n_estimators=100, select__k=20;, score=0.636 total time=   9.9s
# [CV 4/5; 23/28] START model__criterion=entropy, model__n_estimators=100, select__k=20
# [CV 4/5; 23/28] END model__criterion=entropy, model__n_estimators=100, select__k=20;, score=0.648 total time=  10.1s
# [CV 5/5; 23/28] START model__criterion=entropy, model__n_estimators=100, select__k=20
# [CV 5/5; 23/28] END model__criterion=entropy, model__n_estimators=100, select__k=20;, score=0.646 total time=   9.8s
# [CV 1/5; 24/28] START model__criterion=entropy, model__n_estimators=100, select__k=25
# [CV 1/5; 24/28] END model__criterion=entropy, model__n_estimators=100, select__k=25;, score=0.647 total time=  10.2s
# [CV 2/5; 24/28] START model__criterion=entropy, model__n_estimators=100, select__k=25
# [CV 2/5; 24/28] END model__criterion=entropy, model__n_estimators=100, select__k=25;, score=0.648 total time=  11.5s
# [CV 3/5; 24/28] START model__criterion=entropy, model__n_estimators=100, select__k=25
# [CV 3/5; 24/28] END model__criterion=entropy, model__n_estimators=100, select__k=25;, score=0.645 total time=  11.3s
# [CV 4/5; 24/28] START model__criterion=entropy, model__n_estimators=100, select__k=25
# [CV 4/5; 24/28] END model__criterion=entropy, model__n_estimators=100, select__k=25;, score=0.649 total time=  11.0s
# [CV 5/5; 24/28] START model__criterion=entropy, model__n_estimators=100, select__k=25
# [CV 5/5; 24/28] END model__criterion=entropy, model__n_estimators=100, select__k=25;, score=0.648 total time=  11.0s
# [CV 1/5; 25/28] START model__criterion=entropy, model__n_estimators=100, select__k=30
# [CV 1/5; 25/28] END model__criterion=entropy, model__n_estimators=100, select__k=30;, score=0.648 total time=  11.9s
# [CV 2/5; 25/28] START model__criterion=entropy, model__n_estimators=100, select__k=30
# [CV 2/5; 25/28] END model__criterion=entropy, model__n_estimators=100, select__k=30;, score=0.647 total time=  12.4s
# [CV 3/5; 25/28] START model__criterion=entropy, model__n_estimators=100, select__k=30
# [CV 3/5; 25/28] END model__criterion=entropy, model__n_estimators=100, select__k=30;, score=0.645 total time=  12.7s
# [CV 4/5; 25/28] START model__criterion=entropy, model__n_estimators=100, select__k=30
# [CV 4/5; 25/28] END model__criterion=entropy, model__n_estimators=100, select__k=30;, score=0.649 total time=  13.9s
# [CV 5/5; 25/28] START model__criterion=entropy, model__n_estimators=100, select__k=30
# [CV 5/5; 25/28] END model__criterion=entropy, model__n_estimators=100, select__k=30;, score=0.644 total time=  11.5s
# [CV 1/5; 26/28] START model__criterion=entropy, model__n_estimators=100, select__k=35
# [CV 1/5; 26/28] END model__criterion=entropy, model__n_estimators=100, select__k=35;, score=0.647 total time=  11.3s
# [CV 2/5; 26/28] START model__criterion=entropy, model__n_estimators=100, select__k=35
# [CV 2/5; 26/28] END model__criterion=entropy, model__n_estimators=100, select__k=35;, score=0.649 total time=  10.2s
# [CV 3/5; 26/28] START model__criterion=entropy, model__n_estimators=100, select__k=35
# [CV 3/5; 26/28] END model__criterion=entropy, model__n_estimators=100, select__k=35;, score=0.645 total time=   9.7s
# [CV 4/5; 26/28] START model__criterion=entropy, model__n_estimators=100, select__k=35
# [CV 4/5; 26/28] END model__criterion=entropy, model__n_estimators=100, select__k=35;, score=0.650 total time=  10.0s
# [CV 5/5; 26/28] START model__criterion=entropy, model__n_estimators=100, select__k=35
# [CV 5/5; 26/28] END model__criterion=entropy, model__n_estimators=100, select__k=35;, score=0.644 total time=   9.2s
# [CV 1/5; 27/28] START model__criterion=entropy, model__n_estimators=100, select__k=40
# [CV 1/5; 27/28] END model__criterion=entropy, model__n_estimators=100, select__k=40;, score=0.650 total time=  10.5s
# [CV 2/5; 27/28] START model__criterion=entropy, model__n_estimators=100, select__k=40
# [CV 2/5; 27/28] END model__criterion=entropy, model__n_estimators=100, select__k=40;, score=0.649 total time=  10.5s
# [CV 3/5; 27/28] START model__criterion=entropy, model__n_estimators=100, select__k=40
# [CV 3/5; 27/28] END model__criterion=entropy, model__n_estimators=100, select__k=40;, score=0.644 total time=  10.7s
# [CV 4/5; 27/28] START model__criterion=entropy, model__n_estimators=100, select__k=40
# [CV 4/5; 27/28] END model__criterion=entropy, model__n_estimators=100, select__k=40;, score=0.646 total time=  11.3s
# [CV 5/5; 27/28] START model__criterion=entropy, model__n_estimators=100, select__k=40
# [CV 5/5; 27/28] END model__criterion=entropy, model__n_estimators=100, select__k=40;, score=0.645 total time=  10.6s
# [CV 1/5; 28/28] START model__criterion=entropy, model__n_estimators=100, select__k=47
# [CV 1/5; 28/28] END model__criterion=entropy, model__n_estimators=100, select__k=47;, score=0.646 total time=  10.2s
# [CV 2/5; 28/28] START model__criterion=entropy, model__n_estimators=100, select__k=47
# [CV 2/5; 28/28] END model__criterion=entropy, model__n_estimators=100, select__k=47;, score=0.649 total time=   9.5s
# [CV 3/5; 28/28] START model__criterion=entropy, model__n_estimators=100, select__k=47
# [CV 3/5; 28/28] END model__criterion=entropy, model__n_estimators=100, select__k=47;, score=0.646 total time=   9.2s
# [CV 4/5; 28/28] START model__criterion=entropy, model__n_estimators=100, select__k=47
# [CV 4/5; 28/28] END model__criterion=entropy, model__n_estimators=100, select__k=47;, score=0.647 total time=   8.8s
# [CV 5/5; 28/28] START model__criterion=entropy, model__n_estimators=100, select__k=47
# [CV 5/5; 28/28] END model__criterion=entropy, model__n_estimators=100, select__k=47;, score=0.646 total time=   9.6s
# GridSearchCV(estimator=Pipeline(steps=[('select', SelectKBest()),
#                                        ('model',
#                                         RandomForestClassifier(max_depth=15))]),
#              param_grid={'model__criterion': ['gini', 'entropy'],
#                          'model__n_estimators': [50, 100],
#                          'select__k': [15, 20, 25, 30, 35, 40, 47]},
#              verbose=10)

# %%
gs.best_params_
# Out:
# {'model__criterion': 'gini', 'model__n_estimators': 100, 'select__k': 30}

# %%
gs.best_score_
# Out:
# 0.6480035594704827

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
t_pred = rf.predict(X_test_sc)
print("Training Score: ", rf.score(X_train_sc, t_train))
print("Testing Score: ", rf.score(X_test_sc, t_test))
print(classification_report(t_test, t_pred))
fpr, tpr, thresholds = metrics.roc_curve(t_test, t_pred, pos_label=1)
print("AUC ", metrics.auc(fpr, tpr))
# Out:
# Training Score:  0.9999126532662219
# Testing Score:  0.6523533457796993
#               precision    recall  f1-score   support
#
#            0       0.66      0.73      0.69      5433
#            1       0.65      0.56      0.60      4744
#
#     accuracy                           0.65     10177
#    macro avg       0.65      0.65      0.65     10177
# weighted avg       0.65      0.65      0.65     10177
#
# AUC  0.646355115776457
